# %%
import sys
import os
sys.path.append(os.path.abspath(r"\Users\henri\Documents\pythonProjcs\Percolacao_invasiva_2"))
from data_structure.matriz_binaria import Matriz_bi as MB
from data_structure.matriz_fibo import Matriz_fibo as MF
from data_structure.matriz_list import Matriz_lis as ML
from percolacao_invasiva import Percolacao_invasiva as PI
from agoritmos_testes.plot_matriz import PlotMatriz as pltMa

# %%
matriz = MF(2049)
PI().start(matriz)
pltMa._plot(matriz)

# %%
matriz = MF(1025)
PI().start(matriz)
pltMa._plot(matriz)

# %%
matriz = MF(513)
PI().start(matriz)
pltMa._plot(matriz)

# %%
matriz = MF(257)
PI().start(matriz)
pltMa._plot(matriz)

# %%
matriz = MF(4099)
PI().start(matriz)
pltMa._plot(matriz)

# %%
matriz = MF(8193)
PI().start(matriz)
pltMa._plot(matriz)

# %%
matriz = MF(8193)
PI().start(matriz)
pltMa._plot(matriz)
